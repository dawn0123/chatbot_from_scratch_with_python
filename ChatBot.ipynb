# %%
#1 Mounting the Google Drive

from google.colab import drive
drive.mount('/content/drive')
data_root='/content/drive/My Drive/ChatBot' #Please upload the files in your drive and change the path to it accordingly.
# Out:
# Mounted at /content/drive

# %%
#2 Importing Relevant Libraries

import json
import string
import random 

import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer 
import tensorflow as tf 
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense, Dropout
nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
#3 Loading the Dataset: intents.json

data_file = open(data_root + '/intents.json').read()
data = json.loads(data_file)

data
# Out:
# {'intents': [{'context': '',
#    'patterns': ['Hello', 'Hi there', 'Good morning', "What's up"],
#    'responses': ['Hey!', 'Hello', 'Hi!', 'Good morning!'],
#    'tag': 'hello'},
#   {'context': [''],
#    'patterns': [],
#    'responses': ["Sorry, can't understand you",
#     'Please give me more info',
#     'Not sure I understand'],
#    'tag': 'noanswer'},
#   {'context': '',
#    'patterns': ['What is your job', 'What is your work'],
#    'responses': ['My job is to make you feel like everything is okay.',
#     'I work to serve you as well as possible'],
#    'tag': 'job'},
#   {'context': '',
#    'patterns': ['What is your age', 'How old are you', 'When were you born'],
#    'responses': ['I was born in 2021'],
#    'tag': 'age'},
#   {'context': '',
#    'patterns': ['How are you today', 'How are you'],
#    'responses': ['I am feeling good, you?',
#     'Very good and you?',
#     "Actually, I'm okay and you?"],
#    'tag': 'feeling'},
#   {'context': 'feeling',
#    'patterns': ['I am good too',
#     'I feel fine',
#     'Good !',
#     'Fine',
#     'I am good',
#     'I am great',
#     'great'],
#    'responses': ['That is perfect!', "So, everything's okay!"],
#    'tag': 'good'},
#   {'context': 'feeling',
#    'patterns': ['I am feeling bad', 'No I am sad', 'No'],
#    'responses': ['I hope you will feel better !'],
#    'tag': 'bad'},
#   {'context': '',
#    'patterns': ['What can you do', 'What can I ask you', 'Can you help me'],
#    'responses': ['I can do a lot of things but here are some of my skills, you can ask me: the capital of a country, its currency and its area. A random number. To calculate a math operation.'],
#    'tag': 'actions'},
#   {'context': '',
#    'patterns': ['Are you a girl', 'You are a women'],
#    'responses': ['Sure, I am a women'],
#    'tag': 'women'},
#   {'context': '',
#    'patterns': ['Are you a men', 'Are you a boy'],
#    'responses': ['No, I am a women'],
#    'tag': 'men'},
#   {'context': '',
#    'patterns': ['Thank you', 'Thank you very much', 'thanks'],
#    'responses': ['I only do my job️', 'No problem!'],
#    'tag': 'thanks'},
#   {'context': '',
#    'patterns': ['Goodbye', 'Good afternoon', 'Bye'],
#    'responses': ['Goodbye!', 'See you soon!'],
#    'tag': 'goodbye'},
#   {'context': '',
#    'patterns': ['Where do you live'],
#    'responses': ['I live in a server located in the US!'],
#    'tag': 'city'},
#   {'context': '',
#    'patterns': ['What are you doing'],
#    'responses': ["Actually, I'm chatting with somebody"],
#    'tag': 'action'},
#   {'context': '',
#    'patterns': ['Can you wait 2 minutes', 'Please wait', 'Wait 2 secs please'],
#    'responses': ['Sure! I wait.'],
#    'tag': 'wait'},
#   {'context': '',
#    'patterns': ['Are you still there?', 'Are you here?'],
#    'responses': ['Of course! Always at your service.'],
#    'tag': 'still there'}]}

# %%
#4 Extracting data_X(features) and data_Y(Target)

words = [] #For Bow model/ vocabulary for patterns
classes = [] #For Bow  model/ vocabulary for tags
data_X = [] #For storing each pattern
data_y = [] #For storing tag corresponding to each pattern in data_X 
# Iterating over all the intents

for intent in data["intents"]:
    for pattern in intent["patterns"]:
        tokens = nltk.word_tokenize(pattern) # tokenize each pattern 
        words.extend(tokens) #and append tokens to words
        data_X.append(pattern) #appending pattern to data_X
        data_y.append(intent["tag"]) ,# appending the associated tag to each pattern 
    
    # adding the tag to the classes if it's not there already 
    if intent["tag"] not in classes:
        classes.append(intent["tag"])

# initializing lemmatizer to get stem of words
lemmatizer = WordNetLemmatizer()

# lemmatize all the words in the vocab and convert them to lowercase
# if the words don't appear in punctuation
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]
# sorting the vocab and classes in alphabetical order and taking the # set to ensure no duplicates occur
words = sorted(set(words))
classes = sorted(set(classes))

# %%
# 5 Text to Numbers
training = []
out_empty = [0] * len(classes)
# creating the bag of words model
for idx, doc in enumerate(data_X):
    bow = []
    text = lemmatizer.lemmatize(doc.lower())
    for word in words:
        bow.append(1) if word in text else bow.append(0)
    # mark the index of class that the current pattern is associated
    # to
    output_row = list(out_empty)
    output_row[classes.index(data_y[idx])] = 1
    # add the one hot encoded BoW and associated classes to training 
    training.append([bow, output_row])
# shuffle the data and convert it to an array
random.shuffle(training)
training = np.array(training, dtype=object)
# split the features and target labels
train_X = np.array(list(training[:, 0]))
train_Y = np.array(list(training[:, 1]))

# %%
#6 The Neural Network Model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_X[0]),), activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(len(train_Y[0]), activation = "softmax"))
adam = tf.keras.optimizers.Adam(learning_rate=0.01, decay=1e-6)
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=["accuracy"])
print(model.summary())
model.fit(x=train_X, y=train_Y, epochs=150, verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               7552
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                1040
# =================================================================
# Total params: 16,848
# Trainable params: 16,848
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/150
# 2/2 [==============================] - 1s 8ms/step - loss: 2.8014 - accuracy: 0.0244
# Epoch 2/150
# 2/2 [==============================] - 0s 7ms/step - loss: 2.6645 - accuracy: 0.1463
# Epoch 3/150
# 2/2 [==============================] - 0s 18ms/step - loss: 2.5765 - accuracy: 0.2927
# Epoch 4/150
# 2/2 [==============================] - 0s 6ms/step - loss: 2.3987 - accuracy: 0.3171
# Epoch 5/150
# 2/2 [==============================] - 0s 7ms/step - loss: 2.2316 - accuracy: 0.4146
# Epoch 6/150
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0597 - accuracy: 0.3902
# Epoch 7/150
# 2/2 [==============================] - 0s 13ms/step - loss: 1.8662 - accuracy: 0.3902
# Epoch 8/150
# 2/2 [==============================] - 0s 6ms/step - loss: 1.6594 - accuracy: 0.4634
# Epoch 9/150
# 2/2 [==============================] - 0s 8ms/step - loss: 1.6654 - accuracy: 0.5122
# Epoch 10/150
# 2/2 [==============================] - 0s 8ms/step - loss: 1.3711 - accuracy: 0.5366
# Epoch 11/150
# 2/2 [==============================] - 0s 11ms/step - loss: 1.2581 - accuracy: 0.5610
# Epoch 12/150
# 2/2 [==============================] - 0s 15ms/step - loss: 1.2472 - accuracy: 0.7073
# Epoch 13/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.9367 - accuracy: 0.7805
# Epoch 14/150
# 2/2 [==============================] - 0s 5ms/step - loss: 1.0444 - accuracy: 0.6829
# Epoch 15/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.9234 - accuracy: 0.7317
# Epoch 16/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6533 - accuracy: 0.8537
# Epoch 17/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.8585 - accuracy: 0.6829
# Epoch 18/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7158 - accuracy: 0.7561
# Epoch 19/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.8260 - accuracy: 0.7561
# Epoch 20/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5078 - accuracy: 0.9024
# Epoch 21/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4247 - accuracy: 0.8780
# Epoch 22/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5910 - accuracy: 0.7805
# Epoch 23/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4627 - accuracy: 0.8049
# Epoch 24/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3591 - accuracy: 0.8049
# Epoch 25/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4436 - accuracy: 0.8293
# Epoch 26/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4867 - accuracy: 0.8293
# Epoch 27/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2922 - accuracy: 0.9268
# Epoch 28/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2794 - accuracy: 0.9024
# Epoch 29/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5844 - accuracy: 0.7805
# Epoch 30/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4561 - accuracy: 0.8049
# Epoch 31/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4389 - accuracy: 0.8537
# Epoch 32/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2877 - accuracy: 0.9512
# Epoch 33/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2979 - accuracy: 0.9268
# Epoch 34/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3697 - accuracy: 0.8537
# Epoch 35/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2565 - accuracy: 0.9268
# Epoch 36/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3615 - accuracy: 0.8537
# Epoch 37/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3240 - accuracy: 0.8537
# Epoch 38/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2762 - accuracy: 0.9268
# Epoch 39/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1903 - accuracy: 0.9268
# Epoch 40/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2076 - accuracy: 0.8780
# Epoch 41/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1352 - accuracy: 0.9512
# Epoch 42/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3467 - accuracy: 0.9024
# Epoch 43/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2939 - accuracy: 0.9024
# Epoch 44/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2231 - accuracy: 0.9024
# Epoch 45/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2536 - accuracy: 0.9024
# Epoch 46/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2922 - accuracy: 0.9024
# Epoch 47/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1112 - accuracy: 0.9756
# Epoch 48/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2423 - accuracy: 0.9024
# Epoch 49/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1979 - accuracy: 0.9024
# Epoch 50/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1495 - accuracy: 0.9512
# Epoch 51/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1568 - accuracy: 0.9756
# Epoch 52/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2660 - accuracy: 0.9024
# Epoch 53/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2677 - accuracy: 0.9268
# Epoch 54/150
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0802 - accuracy: 1.0000
# Epoch 55/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1366 - accuracy: 0.9512
# Epoch 56/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1190 - accuracy: 0.9268
# Epoch 57/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1928 - accuracy: 0.9756
# Epoch 58/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1699 - accuracy: 0.9268
# Epoch 59/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1563 - accuracy: 0.9512
# Epoch 60/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1247 - accuracy: 0.9756
# Epoch 61/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1019 - accuracy: 0.9756
# Epoch 62/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1363 - accuracy: 0.9512
# Epoch 63/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1932 - accuracy: 0.9268
# Epoch 64/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2659 - accuracy: 0.9268
# Epoch 65/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1567 - accuracy: 0.9756
# Epoch 66/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2105 - accuracy: 0.9024
# Epoch 67/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1316 - accuracy: 0.9268
# Epoch 68/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0652 - accuracy: 1.0000
# Epoch 69/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0844 - accuracy: 0.9756
# Epoch 70/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1119 - accuracy: 0.9756
# Epoch 71/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0580 - accuracy: 0.9756
# Epoch 72/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1253 - accuracy: 0.9756
# Epoch 73/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1525 - accuracy: 0.9512
# Epoch 74/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1118 - accuracy: 0.9268
# Epoch 75/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1680 - accuracy: 0.9512
# Epoch 76/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1311 - accuracy: 0.9268
# Epoch 77/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1564 - accuracy: 0.9512
# Epoch 78/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0442 - accuracy: 1.0000
# Epoch 79/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0905 - accuracy: 0.9512
# Epoch 80/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1820 - accuracy: 0.9512
# Epoch 81/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1818 - accuracy: 0.9512
# Epoch 82/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2064 - accuracy: 0.9756
# Epoch 83/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3250 - accuracy: 0.8780
# Epoch 84/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0701 - accuracy: 0.9756
# Epoch 85/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1716 - accuracy: 0.9512
# Epoch 86/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1492 - accuracy: 0.9756
# Epoch 87/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1072 - accuracy: 0.9756
# Epoch 88/150
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1376 - accuracy: 0.9512
# Epoch 89/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1405 - accuracy: 0.9756
# Epoch 90/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0520 - accuracy: 0.9756
# Epoch 91/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1650 - accuracy: 0.9268
# Epoch 92/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1146 - accuracy: 0.9512
# Epoch 93/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0928 - accuracy: 0.9512
# Epoch 94/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1644 - accuracy: 0.9756
# Epoch 95/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0993 - accuracy: 0.9756
# Epoch 96/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1194 - accuracy: 0.9756
# Epoch 97/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1089 - accuracy: 0.9756
# Epoch 98/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1164 - accuracy: 0.9512
# Epoch 99/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0876 - accuracy: 0.9756
# Epoch 100/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0617 - accuracy: 0.9756
# Epoch 101/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0702 - accuracy: 0.9756
# Epoch 102/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0718 - accuracy: 0.9756
# Epoch 103/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1082 - accuracy: 0.9512
# Epoch 104/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1290 - accuracy: 0.9512
# Epoch 105/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1525 - accuracy: 0.9024
# Epoch 106/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0896 - accuracy: 0.9756
# Epoch 107/150
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0843 - accuracy: 0.9756
# Epoch 108/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1827 - accuracy: 0.9024
# Epoch 109/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1893 - accuracy: 0.9268
# Epoch 110/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1015 - accuracy: 0.9512
# Epoch 111/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1312 - accuracy: 0.9512
# Epoch 112/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1070 - accuracy: 0.9512
# Epoch 113/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0722 - accuracy: 0.9756
# Epoch 114/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0889 - accuracy: 0.9756
# Epoch 115/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1116 - accuracy: 0.9512
# Epoch 116/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0900 - accuracy: 0.9756
# Epoch 117/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0871 - accuracy: 0.9512
# Epoch 118/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0730 - accuracy: 0.9756
# Epoch 119/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0419 - accuracy: 0.9756
# Epoch 120/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0302 - accuracy: 1.0000
# Epoch 121/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1419 - accuracy: 0.9268
# Epoch 122/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1316 - accuracy: 0.9756
# Epoch 123/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1186 - accuracy: 0.9756
# Epoch 124/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1000 - accuracy: 0.9268
# Epoch 125/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1171 - accuracy: 0.9756
# Epoch 126/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0803 - accuracy: 0.9512
# Epoch 127/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1935 - accuracy: 0.9268
# Epoch 128/150
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0763 - accuracy: 0.9756
# Epoch 129/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0541 - accuracy: 1.0000
# Epoch 130/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0478 - accuracy: 0.9756
# Epoch 131/150
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1007 - accuracy: 0.9512
# Epoch 132/150
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0763 - accuracy: 0.9756
# Epoch 133/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0672 - accuracy: 0.9512
# Epoch 134/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0324 - accuracy: 1.0000
# Epoch 135/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1025 - accuracy: 0.9512
# Epoch 136/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0674 - accuracy: 0.9512
# Epoch 137/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0798 - accuracy: 0.9756
# Epoch 138/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1384 - accuracy: 0.9268
# Epoch 139/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0639 - accuracy: 1.0000
# Epoch 140/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0365 - accuracy: 0.9756
# Epoch 141/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1473 - accuracy: 0.9756
# Epoch 142/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1291 - accuracy: 0.9268
# Epoch 143/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0555 - accuracy: 0.9756
# Epoch 144/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0704 - accuracy: 0.9512
# Epoch 145/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1276 - accuracy: 0.9268
# Epoch 146/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0544 - accuracy: 0.9512
# Epoch 147/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1525 - accuracy: 0.9756
# Epoch 148/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0907 - accuracy: 0.9756
# Epoch 149/150
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0869 - accuracy: 0.9756
# Epoch 150/150
# 2/2 [==============================] - 0s 19ms/step - loss: 0.1337 - accuracy: 0.9268

# %%
#7 Preprocessing the Input

def clean_text(text): 
  tokens = nltk.word_tokenize(text)
  tokens = [lemmatizer.lemmatize(word) for word in tokens]
  return tokens

def bag_of_words(text, vocab): 
  tokens = clean_text(text)
  bow = [0] * len(vocab)
  for w in tokens: 
    for idx, word in enumerate(vocab):
      if word == w: 
        bow[idx] = 1
  return np.array(bow)

def pred_class(text, vocab, labels): 
  bow = bag_of_words(text, vocab)
  result = model.predict(np.array([bow]))[0] #Extracting probabilities
  thresh = 0.5
  y_pred = [[indx, res] for indx, res in enumerate(result) if res > thresh]
  y_pred.sort(key=lambda x: x[1], reverse=True) #Sorting by values of probability in decreasing order
  return_list = []
  for r in y_pred:
    return_list.append(labels[r[0]]) #Contains labels(tags) for highest probability 
  return return_list

def get_response(intents_list, intents_json): 
  if len(intents_list) == 0:
    result = "Sorry! I don't understand."
  else:
    tag = intents_list[0]
    list_of_intents = intents_json["intents"]
    for i in list_of_intents: 
      if i["tag"] == tag:
        result = random.choice(i["responses"])
        break
  return result

# %%
# Interacting with the chatbot
print("Press 0 if you don't want to chat with our ChatBot.")
while True:
    message = input("")
    if message == "0":
      break
    intents = pred_class(message, words, classes)
    result = get_response(intents, data)
    print(result)
# Out:
# Press 0 if you don't want to chat with our ChatBot.
# hi
# Good morning!
# How are you
# Sorry! I don't understand.
# Hello
# That is perfect!
# how do you do
# Actually, I'm okay and you?
# I am good too.
# That is perfect!
# Yes, bye.
# Goodbye!
# 0
